# %% [markdown]
# # RAG Evaluation - Fully Custom Test Set Generation
#
# **Approach:** Pure Custom Generation (No RAGAS)
#
# **Pipeline:**
# 1. Spatial division (4 regions) + Recursive chunking
# 2. Custom question generation (all types)
# 3. Multi-turn conversation generation
# 4. Automatic classification
# 5. Quality filtering
# 6. Coverage analysis & export
#
# **Question Types Supported:**
# - chatbot_style, direct_factual, procedural, analytical, compliance
# - multi_turn, simple, contextual, reasoning
# - descriptive, multi_hop, comparative, conditional, unanswerable
#
# **Goal:** Full control over question quality, types, and coverage

# %% [markdown]
# ## 1. Setup & Imports

# %%
# Install required packages (run once)
#!pip install langchain langchain-openai langchain-text-splitters langchain-community pandas numpy matplotlib tqdm

# %%
import os
import json
import pandas as pd
import numpy as np
import re
from pathlib import Path
from typing import List, Dict, Any, Optional
from dataclasses import dataclass, field
from tqdm.notebook import tqdm

# LangChain
from langchain_openai import AzureChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.prompts import PromptTemplate
from langchain_core.documents import Document

# Visualization
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

print("✅ All imports successful")
# Out:
# ✅ All imports successful

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class CustomConfig:
    """Fully Custom Generation Configuration"""
    
    # Azure OpenAI Settings
    azure_endpoint: str = "https://your-endpoint.openai.azure.com/"
    azure_api_key: str = "your-api-key"
    azure_api_version: str = "2024-02-01"
    azure_deployment_gpt4: str = "gpt-4"
    
    # Coverage Strategy
    num_spatial_regions: int = 4
    questions_per_document: int = 20
    questions_per_region: int = 5
    
    # Chunking
    chunk_size: int = 1500
    chunk_overlap: int = 300
    
    # Question Type Distribution
    question_type_distribution: Dict[str, float] = field(default_factory=lambda: {
        "chatbot_style": 0.10,
        "direct_factual": 0.10,
        "procedural": 0.15,
        "scenario": 0.20,
        "analytical": 0.10,
        "compliance": 0.05,
        "descriptive": 0.10,
        "multi_hop": 0.10,
        "comparative": 0.05,
        "conditional": 0.05,
    })
    
    # Conversation Type Distribution
    single_turn_ratio: float = 0.60
    multi_turn_ratio: float = 0.40
    max_turns_per_conversation: int = 3
    
    # Domain
    domain_name: str = "Banking and Financial Services (BIS)"
    domain_context: str = "BIS Meeting Services, regulatory compliance, operational procedures"
    
    # LLM Parameters
    temperature: float = 0.7
    max_tokens: int = 3000
    
    # Quality
    min_quality_score: float = 7.0

config = CustomConfig()

print("✅ Configuration loaded")
print(f"   Questions per document: {config.questions_per_document}")
print(f"   Multi-turn ratio: {config.multi_turn_ratio * 100}%")
print(f"   Question types: {len(config.question_type_distribution)}")
# Out:
# ✅ Configuration loaded
#    Questions per document: 20
#    Multi-turn ratio: 40.0%
#    Question types: 10

# %%
# UPDATE YOUR AZURE CREDENTIALS HERE

config.azure_endpoint = os.getenv("AZURE_OAI_ENDPOINT")
config.azure_api_key = os.getenv("AZURE_OAI_API_KEY")
config.azure_deployment_gpt4 = os.getenv("AZURE_OAI_DEPLOYMENT")
config.azure_api_version = os.getenv("AZURE_OAI_API_VERSION")


print("✅ Credentials configured")
# Out:
# ✅ Credentials configured

# %% [markdown]
# ## 3. Initialize LLM

# %%
llm = AzureChatOpenAI(
    azure_endpoint=config.azure_endpoint,
    api_key=config.azure_api_key,
    api_version=config.azure_api_version,
    deployment_name=config.azure_deployment_gpt4,
    temperature=config.temperature,
    max_tokens=config.max_tokens,
)

# Test
test_response = llm.invoke("Say 'Ready'")
print(f"✅ LLM Test: {test_response.content}")
# Out:
# ✅ LLM Test: Ready

# %% [markdown]
# ## 4. Document Loading & Chunking

# %%
DOCUMENTS_DIR = "./documents"
Path(DOCUMENTS_DIR).mkdir(parents=True, exist_ok=True)


from tqdm import tqdm  # Use standard tqdm

def load_documents(documents_dir: str) -> List[Document]:
    documents = []
    doc_dir = Path(documents_dir)
    
    # Load PDFs
    pdf_files = list(doc_dir.glob("*.pdf"))
    for pdf_file in tqdm(pdf_files, desc="Loading PDFs"):
        try:
            loader = PyPDFLoader(str(pdf_file))
            docs = loader.load()
            for doc in docs:
                doc.metadata["source_file"] = pdf_file.name
                doc.metadata["file_type"] = "pdf"
            documents.extend(docs)
        except Exception as e:
            print(f"Error loading {pdf_file.name}: {e}")
    
    return documents

# Load documents
documents = load_documents(DOCUMENTS_DIR)

print(f"\n✅ Total documents loaded: {len(documents)}")

if len(documents) == 0:
    print("⚠️  No documents found!")
    print(f"   Please add PDF or DOCX files to: {DOCUMENTS_DIR}")
else:
    # Group by source file
    files = {}
    for doc in documents:
        source = doc.metadata.get("source_file", "unknown")
        files[source] = files.get(source, 0) + 1
    
    print("\nDocuments by file:")
    for file, count in files.items():
        print(f"  - {file}: {count} pages/sections")
# Out:
# Loading PDFs: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# ✅ Total documents loaded: 26
#
# Documents by file:
#   - othp33.pdf: 26 pages/sections

# %%
def chunk_documents(documents: List[Document], config: CustomConfig) -> Dict[str, List[Document]]:
    """Chunk documents by source file"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=config.chunk_size,
        chunk_overlap=config.chunk_overlap,
        separators=["\n\n", "\n", ". ", " ", ""],
    )
    
    # Group by source
    docs_by_file = {}
    for doc in documents:
        source = doc.metadata.get("source_file", "unknown")
        if source not in docs_by_file:
            docs_by_file[source] = []
        docs_by_file[source].append(doc)
    
    # Chunk each file
    chunked_docs = {}
    for source, docs in docs_by_file.items():
        combined_text = "\n\n".join([d.page_content for d in docs])
        combined_doc = Document(page_content=combined_text, metadata={"source_file": source})
        chunks = text_splitter.split_documents([combined_doc])
        
        for i, chunk in enumerate(chunks):
            chunk.metadata["chunk_index"] = i
            chunk.metadata["total_chunks"] = len(chunks)
        
        chunked_docs[source] = chunks
        print(f"  ✓ {source}: {len(chunks)} chunks")
    
    return chunked_docs

if documents:
    chunked_docs_by_file = chunk_documents(documents, config)
    print(f"\n✅ Chunking complete")
else:
    chunked_docs_by_file = {}
    print("⚠️  No documents to chunk")
# Out:
#   ✓ othp33.pdf: 69 chunks
#
# ✅ Chunking complete

# %%
def sample_chunks_spatial(chunks: List[Document], n_samples: int, num_regions: int) -> List[Document]:
    """Sample chunks evenly from spatial regions"""
    total = len(chunks)
    if total == 0:
        return []
    
    region_size = total // num_regions
    samples_per_region = n_samples // num_regions
    
    sampled = []
    for region_idx in range(num_regions):
        start = region_idx * region_size
        end = start + region_size if region_idx < num_regions - 1 else total
        region_chunks = chunks[start:end]
        
        if len(region_chunks) > 0:
            step = max(1, len(region_chunks) // samples_per_region)
            selected = region_chunks[::step][:samples_per_region]
            for chunk in selected:
                chunk.metadata["region_id"] = region_idx
            sampled.extend(selected)
    
    return sampled[:n_samples]

# Sample chunks from each document
sampled_chunks_by_file = {}
for source, chunks in chunked_docs_by_file.items():
    sampled = sample_chunks_spatial(chunks, config.questions_per_document, config.num_spatial_regions)
    sampled_chunks_by_file[source] = sampled
    print(f"{source}: Sampled {len(sampled)} chunks")

print(f"\n✅ Sampling complete")
# Out:
# othp33.pdf: Sampled 20 chunks
#
# ✅ Sampling complete

# %%
sampled_chunks_by_file
# Out:
# {'othp33.pdf': [Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 0, 'total_chunks': 69, 'region_id': 0}, page_content='European Central Bank\nBank of Japan\nSveriges Riksbank\nSwiss National Bank\nBank of England\nBoard of Governors Federal Reserve System\nBank for International Settlements\nBank of Canada\nCentral bank digital currencies: \nfoundational principles and core features\nin a series of collaborations \nfrom a group of central banks \nReport no 1 \n\n  \n \n  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nThis publication is available on the BIS website (www.bis.org).  \n \n \n \n© Bank for International Settlements 2020. All rights reserved. Brief excerpts may be reproduced or \ntranslated provided the source is stated.  \n \nISBN: 978-92-9259-427-5 (online)'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 3, 'total_chunks': 69, 'region_id': 0}, page_content='4 CBDC design and technology .................................................................................................................................. 12 \n4.1 Design choices ...................................................................................................................................................... 12 \n4.2 Technology considerations .............................................................................................................................. 13 \n4.3 Key trade-offs ........................................................................................................................................................ 15 \n5. Concluding thoughts and next steps .................................................................................................................... 16 \nReferences .......................................................................................................................................................................................... 18 \nAnnex A: Questions to guide further research .................................................................................................................... 19 \nAnnex B: Group members ............................................................................................................................................................ 20'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 6, 'total_chunks': 69, 'region_id': 0}, page_content='money; and (iii) a CBDC should promote innovation and efficiency. The possible adverse impact of a CBDC \non bank funding and financial intermediation, including the potential for destabilising runs into central \nbank money, has been a concern of central banks. Any decision to launch a CBDC would depend on an \ninformed judgment that these risks can be managed, likely through some combination of safeguards \nincorporated in the design of a CBDC and financial system policies more generally. Understanding the \npotential market struc ture effects of CBDC, their implications for financial stability, and any potential \nmitigants is a further area of work for this group.  \nA CBDC robustly meeting these criteria and delivering the features set out by this group could \nbe an important instrument for central banks to deliver their public policy objectives.  \nThis potential, together with the agreement on common principles and features, means there is \nconsiderable scope for future international collaboration, knowledge -sharing and experimentation on \nCBDC. Simultaneous research and development of CBDC by central banks could also explore ways to \nimprove cross-border payments, as part of the G20 roadmap (CPMI (2020)), while avoiding spillovers and \nunintended consequences.  \nThe next stage of CBDC resea rch and development will emphasise individual and collective \npractical policy analysis and applied technical experimentation by central banks. This report highlights'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 9, 'total_chunks': 69, 'region_id': 0}, page_content='domestic CBDCs in accord with related international workstreams (eg  the G20 roadmap on cross -border \npayments) We welcome further BIS information sharing on CBDC and BIS Innovation Hub plans to explore \nthe technologies that could support CBDCs.  \n1. Introduction  \nCentral banks have a mandate for monetary and financial stabi lity in their jurisdictions and, explicitly or \nimplicitly, to promote broad access to safe and efficient payments. A core instrument by which central \nbanks carry out their public policy objectives is providing the safest form of money to banks, businesses \nand the public – central bank money.  \nThis money acts as a means of payment, unit of account and store of value for a jurisdiction. A \ncommon unit of account is a public good that allows goods and services to be exchanged and financial \ntransactions to be settled efficiently and safely. Today, central banks provide money to the public through \ncash and to banks and other financial companies through reserve and settlement accounts. In this way, \nsome of the smallest and largest payments in an economy are carried  out using central bank money. Yet \nthe ongoing digitalisation of the economy is changing the way people pay. The use of cash, currently the \nonly form of central bank money available to the public, is falling in many jurisdictions. The Covid -19 \npandemic may  be accelerating this trend. Taking cash’s place is private digital money and alternative \npayment methods.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 12, 'total_chunks': 69, 'region_id': 0}, page_content='Central bank digital currencies: foundational principles and core features 3 \n \n \n1.1 The report \nThis report starts by examining central banks’ motivations and evaluates some of the opportunities driving \nCBDC research. In  this context, some foundational principles for central banks’ role in payment systems \nare then articulated together with the core features required of any CBDC for it to fulfil public policy \nobjectives. To realise these core features, a suitable design for a CBDC and its underlying system must be \ndeveloped. This report highlights some of the key design choices and where the policy trade -offs and \ntechnology challenges currently lie for central banks. The report concludes with thoughts on future work \nand some recommendations for where and how international collaboration can aid future domestic policy \ndiscussions.  \n1.2 CBDC explained  \nCBDC is “a digital form of central bank money that is different from balances in traditional reserve or \nsettlement accounts” (CPMI-MC (2018)). Interest in this new form of money is increasing and central banks \nare researching and experimenting with underlying technology . At the same time, private experiments \nwith new forms of digital money continue and the conceptual variety afforded by new technologies has \nmeant that, although CBDC is well defined, this definition is not always well understood.  \nA CBDC is a digital payment instrument, denominated in the national unit of account , that is a'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 17, 'total_chunks': 69, 'region_id': 1}, page_content='CBDC.  \nThere might be a useful role for privately issued liabilitie s matched with central bank money in a \njurisdiction’s payment system (Kahn et al (2018)). However, the  necessary information and decision-m aking \nprocess for a central bank to enable such an arrangement is very different from a consideration of issuing CBDC. \n\uf081The value of a financial system based on narrow banking or “full-reserve banking” has been debated for hundreds of years. Bossone \n(2001) provides an overview of the arguments.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 20, 'total_chunks': 69, 'region_id': 1}, page_content='system could quickly threaten a significant number of users and their confidence in the wider system (as \nit could for a large bank or payment service provider). Defending against cyber attacks will be made more \ndifficult as the number of endpoints in a general  purpose CBDC system will be significantly larger than \nthose of current wholesale central bank systems. \n2.1.3 Increased payments diversity  \nPayment systems, like other infrastructure, benefit from strong network effects, potentially leading to \nconcentration and monopolies or fragmentation. Payment service providers have the incentive to organise \ntheir platforms as closed-loop systems. When a small number of systems dominate, high barriers to entry \nand high costs (especially for merchants) can occur. Whe re more systems exist, fragmentation may still  \noccur as systems often have proprietary messag ing standards, increasing the cost and complexity of \n \n3  However, this increase in resilience assumes that other payment methods and instruments remain available.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 23, 'total_chunks': 69, 'region_id': 1}, page_content='motivation t o issue a CBDC, central banks are expected to design CBDCs  that conform to  these \nrequirements (along with any other regulatory expectations or disclosure laws).  \nFor a CBDC and its system, payments data will exist, and a key national policy question will b e \ndeciding who can access which parts of it and under what circumstances. 6 Striking this balance between \npublic privacy (especially as  data protection legislation continues to evolve ) and reducing illegal activity  \nwill require strong coordination with relevant domestic government agencies (eg tax authorities).   \n2.1.7 Facilitating fiscal transfers  \nFor some jurisdictions, the Covid -19 pandemic illustrates the benefits of having efficient facilities for the \ngovernment to quickly transfer funds to the public and businesses in a crisis. A CBDC system with identified \nusers (eg a system linked to a national digital identity scheme) could be used for these payments.  \n \n4  At a user level, cash could theoretically fulfil the same function but transferring from electronic to physical and back to electronic \nmoney is costly and inconvenient. At a payment provider level, existing wholesale central bank payment systems already fulfil \nthis role. Yet not all payment service providers will be eligible or want to participate.  \n5  Causes of exclusion can include: (i) depository institutions being unable to offer profitable services to users in certain'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 26, 'total_chunks': 69, 'region_id': 1}, page_content='(2019), BoT and HKMA (2020)).  \nCBDC could be used for cross-border payments in different ways. A domestic CBDC could be used for \npayments from, to and perhaps even within another currency area. This could facilitate efficiency but may also \ncreate risks for the foreign jurisdiction. Additionally, CBDC systems could be designed to interoperate to facilitate \ncross-border and cross-currency payments. Interoperability is a broadly understood term and potentially covers \na multitude of different ways payment systems or arrangements can interact with one another. At a basic technical \nlevel, this can involve reducing the barriers to membership of both systems, eg through common messaging \nstandards and overlapping operating times. Moving beyond this, coordination between t he systems can extend \nto common business arrangements, eg a designated settlement agent between the systems for certain payments. \nAnother means is integration of the systems through an interoperable link where the infrastructures combine \ntheir functions (eg arrangements where there are multiple CBDCs (Auer et al (2020)).  \nA future challenge with interoperability might be the number and diversity of payment systems \ndomestically and internationally. CBDC systems will enter a crowded field of domestic payment systems and \ninteroperability can enable complementarity and coexistence. For cross -border payments, closed-loop systems'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 29, 'total_chunks': 69, 'region_id': 1}, page_content='8 Central bank digital currencies: foundational principles and core features \n \n \n2.2 Monetary policy motivations and risks  \nCPMI-MC (2018) included “interest-bearing” as one of the five key design features of a CBDC and provided \na thorough overview of the academic debates around conceptual possibilities. Theoretically, a  \nremunerated CBDC could pa ss on policy rate changes  immediately to CBDC holders  (which might also \nincentivise banks to pass on rates faster too). However, beyond the theory, there are challenges and risks. \nTo be effective in transmitting policy rates, a remunerated CBDC would need to pay competitive rates and \nallow the public to hold significant amounts. This could exacerbate financial stability risks associated with \ndisintermediating banks and making fund flows more volatile (discussed below).7  \nBeyond bearing interest, there has also been public discussion about CBDC use to stimulate \naggregate demand through direct transfers to the public (so-called “helicopter drops”), possibly combined \nwith “programmable monetary policy ” (eg transfers with an “expiry date” or conditional on being spent \non certain goods). However, a key challenge for these transfers is identifying recipients and their accounts. \nA CBDC is not a precondition or necessarily useful, while also potentially blurring the separation between \nmonetary and fiscal policy in ways which should be better understood and mitigated. Although a CBDC'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 34, 'total_chunks': 69, 'region_id': 2}, page_content='central banks to deliver on their public policy responsibilities . Yet they also present new opportunities to \nmake improvements and address long-running issues.  \nA central bank’s decision to embark on issuing a CBDC will require assessing the value of \nopportunities to further pursue its objectives, balanced against any risks. The most valuable opportunities \nthat encourage issuance will be where a CBDC can support a central bank’s public policy objectives. Other \nopportunities abound (eg reducing illegal activity, facilitating fis cal transfers or enabling “programmable \nmoney”), yet unless these have a bearing on a central bank’s objectives, they will be secondary \nconsiderations.  \nFinally, central banks serve jurisdictions with hugely differing financial systems, economies, \nsocieties and legal structures. The motivations and risks balanced by different central banks will vary \nsignificantly. However, given that central banks have common objectives, common principles and \nrequirements for a CBDC are possible. These are developed in the next section.    \n  \n \n8  Even in a case where a stablecoin is denominated in the domestic currency of a jurisdiction, there is a risk that the payment \nsystem and the data that comes along with operating the payment system will be in foreign hands and beyond the control of \ndomestic institutions. \n9  Although it may also increase the risk to other jurisdictions if there is insufficient control and coordination.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 37, 'total_chunks': 69, 'region_id': 2}, page_content='jurisdiction’s payment system, users may adopt other, less safe instruments  or currencies. Ultimately this \ncould lead to economic and consumer harm, potentially damaging monetary and financial stability. The \npayments ecosystem is comprised of public authorities (in particular the central bank) and private agents \n(eg commercial banks and payment service providers). There is a role for the public and private sectors in \nthe supply of payment services to create a safe, efficient and accessible system. Private economic agents \nshould generally be free to decide which means of payment they use to conduct their transactions.\n10  \n \n \n \n \n10  Although for merchants, sometimes “legal tender” legislation requires them to accept certain means of payment in certain \ncircumstances.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 40, 'total_chunks': 69, 'region_id': 2}, page_content='Standards A CBDC system (infrastructure and participating entities ) will need to conform to the \nappropriate regulatory standards (eg entities offering transfer, storage or custody of \nCBDC should be held to equivalent regulatory and prudential standards as firms offering \nsimilar services for cash or existing digital money).'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 43, 'total_chunks': 69, 'region_id': 2}, page_content='calibration challenges for central banks and users.  \n4.1.2 Ledger designs \nIn a CBDC system, a payment is a transfer of a central bank liability, recorded on a ledger. In designing a \nCBDC ledger, there are five key factors: (i) structure; (ii) payment authentication; (iii) functionality; (iv) \naccess; and (v) governance. Each design factor will have a bearing on how a CBDC system meets the core \nfeatures set out earlier.  \nA ledger’s structure could be centralised, decentralised (eg through use of distributed ledger \ntechnology) or a combination (eg a centralised ledger could record only the total CBDC issued, with \nindividual balances stored locally on a smartphone or card ). A centralised ledger would require an \nintermediary to manage and transfer the liabilities, making anti- fraud and security features easier to \nincorporate, whereas a decentralised ledger could have the potential to make peer -to-peer and offline \npayments easier. A combination could be developed but the resulting complexity could create a significant \nburden on the functioning of a system. \nPayment authentication designs (eg identity -based, token-based or multifactor) will drive the \nunderlying data structure of a CBDC system and determine how it will integrate with others (eg for digital \nidentity verification as part of know -your-customer (KYC) or transaction monitoring requirements) in'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 46, 'total_chunks': 69, 'region_id': 2}, page_content='private cross-subsidy or allowing access to consumer data is permitted.  \n4.2 Technology considerations \nIssuing a CBDC and meeting policy goals will require suitable technologies. A variety of \ncomplementary technologies could potentially support the core features. However, any conclusions will \nrequire extensive practical testing and experimentation (Table 2).'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 51, 'total_chunks': 69, 'region_id': 3}, page_content='Central bank digital currencies: foundational principles and core features 15 \n \n \n4.3 Key trade-offs \nAny CBDC and its underlying system will face competing pressures for design choices (eg fast processing \nversus stronger security, which adds processing time). This is true of any system. The potential complexities \nof any CBDC ecosystem and the interlinkages between design choices create multifaceted trade- offs. \nAlthough some trade-offs can be alleviated through technological innovation, there are still uncertainties. \nDetailed engagement with end users, businesses and ecosystem partners can help a central bank clarify \nthese for its own jurisdiction. Some broad examples of system trade -offs are discussed below. However, \nthis is not a complete list and mostly serves to highlight open questions for any CBDC development \n(summarised in Annex A). \nThe trade-offs between an interest-bearing CBDC and the potential financial stability impact on \nthe banking system are discussed above and in CPMI -MC (2018). Significantly more work is required to \nreally understand the trade -offs. A further practical conside ration here is that it is currently easier to \ncalculate and pay interest using a centralised ledger. Using only a centralised ledger potentially reduces \nthe payments convenience of a CBDC (eg making peer -to-peer and offline payments more difficult, or \nsubject to caps) and using a combination of centralised and decentralised ledgers adds complexity to the'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 54, 'total_chunks': 69, 'region_id': 3}, page_content='16 Central bank digital currencies: foundational principles and core features \n \n \n5. Concluding thoughts and next steps  \n5.1 Concluding thoughts \nUnderstanding of CBDCs has advanced significantly in t he last few years. Published research, policy work \nand proofs -of-concept from central banks have gone a long way towards  establishing the practical \nbenefits and challenges in any issuance. Progress has accompanied a gradual convergence on definitions  \nand terms and an improved understanding of the capabilities of current technologies. Many central banks \nare actively engaging the public through reports, speeches and parliamentary hearings. A CBDC, as the \ndigital claim on a central bank, is just a different manifestation of the same unit of account, store of value \nand medium of exchange already offered by central banks.  \nThere is considerable agreement amongst the central banks in this group on the foundational \nprinciples which will guide our ongoing research o n CBDC. This report highlights a set of practical, \ncommon features which build on these principles. The central banks in this group expect these features \nwould have to be incorporated in some fashion by any potential CBDC design, so that it can deliver on the \npublic policy objectives. To achieve these objectives, a CBDC must be convertible, convenient, accessible \nand low cost. The underlying system should be resilient, available 24/7, flexible, interoperable, private and'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 57, 'total_chunks': 69, 'region_id': 3}, page_content='safe payments domestically through a mix of commercial banks, other payment service providers and cash. \nYet each has evolved over time, with an understandably domestic focus.  \nDifferences between jurisdictions persist and policy and design choices do too. Any CBDC will \nbe, first and foremost, designed for domestic users and the domestic payment system. Meeting each \njurisdiction’s requirements  will mean there can be no such thing as an “off- the-shelf” CBDC. Economic \ndesign decisions on CBDC remuneration policy and any controls or tools to manage the impact on the \nbanking system will vary by jurisdiction.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 60, 'total_chunks': 69, 'region_id': 3}, page_content='on cross -border payments and subsequent work on building block 19 on C BDC (“factor an \ninternational dimension into CBDC designs”), led by the CPMI and the BIS.  \n2. We invite the BIS to continue promoting information-sharing and collaboration between central \nbanks on CBDC research.  \n3. We invite the BIS Innovation Hub to explore fu rther technological experiments that could \nsupport our work and we support their plans to explore the technologies that could enable \ninteroperability and cross-border transactions between domestic CBDCs.  \n4. We will continue domestic outreach efforts to foste r an open and informed dialogue on CBDC \nin our jurisdictions. We will provide domestic stakeholders with opportunities to participate in \nthis dialogue. We will reach out to other central banks, including in developing economies, and \nto international organisations.'),
#   Document(metadata={'source_file': 'othp33.pdf', 'chunk_index': 63, 'total_chunks': 69, 'region_id': 3}, page_content='ledger environment, February.  \nFerrari, M, A Mehl and L Stracca (2020): Central bank digital currency in the open economy, forthcoming.  \nG7 Working Group on Stablecoins (2019): Investigating the impact of global stablecoins , October.  \nKahn, C, F Rivadeneyra and R Wong (2018): “ Should the central bank issue e -money?”, Bank of Canada \nStaff Working Paper, 2018-58, December.  \nSveriges Riksbank (2018): The Riksbank’s e-krona project, report 2, October.')]}

# %% [markdown]
# ## 5. Question Generation Prompts (All Types)

# %%
# Master Question Generation Prompt
QUESTION_GENERATION_PROMPT = """
You are a professional test question generator for {domain_name}.

DOCUMENT CONTEXT:
{context}

QUESTION TYPE: {question_type}

QUESTION TYPE DEFINITIONS:

1. **chatbot_style**: Conversational, help-seeking questions
   Example: "Can you help me understand the meeting room booking policy?"
   Example: "I need assistance with the escalation procedure. What should I do?"

2. **direct_factual**: Direct, specific factual questions
   Example: "What is the escalation timeframe for Priority 1 incidents?"
   Example: "How many approval stages are required for external meetings?"

3. **procedural**: Step-by-step process questions
   Example: "What are the steps to book a meeting room for external participants?"
   Example: "Describe the complete workflow for compliance violation reporting."

4. **scenario**: Realistic business situation questions
   Example: "A client requests an urgent meeting room for tomorrow at 8 AM, but all rooms are booked. The client is a senior regulatory official. What should the coordinator do?"

5. **analytical**: Analysis, evaluation, or comparison questions
   Example: "Analyze the differences between Priority 1 and Priority 2 incident response protocols."
   Example: "What factors determine whether a meeting requires executive approval?"

6. **compliance**: Regulatory or policy questions
   Example: "According to MiFID II requirements, what documentation must be retained for investment advisory meetings?"

7. **descriptive**: Questions requiring detailed descriptions
   Example: "Describe the roles and responsibilities of the compliance officer in the escalation process."

8. **multi_hop**: Questions requiring multiple pieces of information
   Example: "If a Priority 1 incident occurs during non-business hours and the primary contact is unavailable, what is the backup procedure and who has the authority to approve emergency measures?"

9. **comparative**: Questions comparing two or more items
   Example: "Compare the booking procedures for internal meetings versus external meetings with regulatory participants."

10. **conditional**: Questions with if-then scenarios
    Example: "If a meeting room booking is cancelled less than 24 hours in advance, what are the consequences and alternative options?"

QUALITY REQUIREMENTS:
- Be SPECIFIC: Reference sections, timeframes, roles, procedures
- Use PROFESSIONAL language appropriate for the type
- Include CONTEXT: Who, what, when, where relevant to type
- Make ANSWERABLE from the document context provided
- Avoid GENERIC questions that could apply to any document

OUTPUT FORMAT (JSON):
{{
    "question": "Your specific question here",
    "answer": "Complete, detailed answer based on the context",
    "question_type": "{question_type}",
    "complexity": "easy|medium|hard",
    "references": ["Section X", "Page Y"] or []
}}

Generate ONE {question_type} question now:
"""

print("✅ Question generation prompt defined")
# Out:
# ✅ Question generation prompt defined

# %%
# Follow-up Question Generation Prompt
FOLLOWUP_GENERATION_PROMPT = """
You are generating a FOLLOW-UP question for a multi-turn conversation.

DOCUMENT CONTEXT:
{context}

INITIAL QUESTION:
{initial_question}

INITIAL ANSWER:
{initial_answer}

FOLLOW-UP REQUIREMENTS:
1. **Build on the initial question** - Reference or extend it naturally
2. **Dig deeper** - Ask for more detail, exceptions, edge cases, or consequences
3. **Maintain context** - Assume the initial answer is known
4. **Be conversational** - Natural progression of the conversation

FOLLOW-UP TYPES:
- **Clarification**: "In the procedure you mentioned, what happens if X?"
- **Edge case**: "What if the standard approach doesn't apply because Y?"
- **Deeper detail**: "For the documentation requirement, how long must records be retained?"
- **Consequence**: "After following that procedure, what are the next steps?"
- **Exception**: "Are there any circumstances where this rule can be waived?"

OUTPUT FORMAT (JSON):
{{
    "followup_question": "Your follow-up question here",
    "followup_answer": "Complete answer to the follow-up",
    "followup_type": "clarification|edge_case|deeper_detail|consequence|exception"
}}

Generate ONE follow-up question now:
"""

print("✅ Follow-up generation prompt defined")
# Out:
# ✅ Follow-up generation prompt defined

# %% [markdown]
# ## 6. Question Generation Functions

# %%
def generate_question(chunk: Document, question_type: str, config: CustomConfig) -> Optional[Dict]:
    """Generate a single question of specified type"""
    prompt = QUESTION_GENERATION_PROMPT.format(
        context=chunk.page_content[:2500],
        question_type=question_type,
        domain_name=config.domain_name
    )
    
    try:
        response = llm.invoke(prompt)
        content = response.content.strip()
        
        # Clean JSON from markdown
        content = re.sub(r'^```json\s*', '', content)
        content = re.sub(r'\s*```$', '', content)
        content = content.strip()
        
        result = json.loads(content)
        result['source_file'] = chunk.metadata.get('source_file', 'unknown')
        result['chunk_index'] = chunk.metadata.get('chunk_index', 0)
        result['region_id'] = chunk.metadata.get('region_id', 0)
        return result
    except Exception as e:
        print(f"  ⚠️  Error generating {question_type}: {str(e)[:100]}")
        return None

def generate_followup(initial_qa: Dict, chunk: Document) -> Optional[Dict]:
    """Generate a follow-up question"""
    prompt = FOLLOWUP_GENERATION_PROMPT.format(
        context=chunk.page_content[:2500],
        initial_question=initial_qa['question'],
        initial_answer=initial_qa['answer']
    )
    
    try:
        response = llm.invoke(prompt)
        content = response.content.strip()
        content = re.sub(r'^```json\s*', '', content)
        content = re.sub(r'\s*```$', '', content)
        content = content.strip()
        result = json.loads(content)
        return result
    except Exception as e:
        print(f"  ⚠️  Error generating follow-up: {str(e)[:100]}")
        return None

print("✅ Generation functions defined")
# Out:
# ✅ Generation functions defined

# %% [markdown]
# ## 7. Generate Test Set

# %%
# TEST MODE
TEST_MODE = True
TEST_QUESTIONS_PER_DOC = 50

if TEST_MODE:
    print(f"⚠️  TEST MODE: Generating only {TEST_QUESTIONS_PER_DOC} questions per document")
    print("   Set TEST_MODE = False for full generation\n")
    questions_to_generate = TEST_QUESTIONS_PER_DOC
else:
    questions_to_generate = config.questions_per_document

def get_question_type_sequence(n_questions: int, distribution: Dict[str, float]) -> List[str]:
    """Create question type sequence based on distribution"""
    sequence = []
    for q_type, ratio in distribution.items():
        count = max(1, int(n_questions * ratio))
        sequence.extend([q_type] * count)
    
    import random
    random.shuffle(sequence)
    return sequence[:n_questions]

print("✅ Ready to generate questions")
# Out:
# ⚠️  TEST MODE: Generating only 50 questions per document
#    Set TEST_MODE = False for full generation
#
# ✅ Ready to generate questions

# %%
# Generate questions for all documents
all_questions = []

for source_file, sampled_chunks in sampled_chunks_by_file.items():
    print(f"\n{'='*70}")
    print(f"Generating questions for: {source_file}")
    print(f"{'='*70}")
    
    # Get question type sequence
    question_types = get_question_type_sequence(questions_to_generate, config.question_type_distribution)
    
    print(f"\nQuestion type breakdown:")
    for q_type in set(question_types):
        count = question_types.count(q_type)
        print(f"  - {q_type}: {count}")
    
    # Decide which questions get follow-ups (multi-turn)
    n_multiturn = int(len(question_types) * config.multi_turn_ratio)
    multiturn_indices = np.random.choice(len(question_types), n_multiturn, replace=False)
    
    doc_questions = []
    
    for idx, (chunk, q_type) in enumerate(tqdm(list(zip(sampled_chunks[:questions_to_generate], question_types)), 
                                                desc="Generating")):
        # Generate initial question
        qa = generate_question(chunk, q_type, config)
        
        if qa:
            qa['conversation_type'] = 'multi_turn' if idx in multiturn_indices else 'single_turn'
            qa['turn_number'] = 1
            qa['parent_question_id'] = None
            qa['has_followup'] = False
            qa['followup_questions'] = []
            
            doc_questions.append(qa)
            
            # Generate follow-ups if multi-turn
            if idx in multiturn_indices:
                n_turns = np.random.randint(1, config.max_turns_per_conversation)
                followups = []
                
                for turn in range(n_turns):
                    followup = generate_followup(qa, chunk)
                    if followup:
                        followups.append(followup)
                
                if followups:
                    qa['has_followup'] = True
                    qa['followup_questions'] = followups
    
    all_questions.extend(doc_questions)
    
    print(f"\n✅ Generated {len(doc_questions)} questions")
    print(f"   - Single-turn: {sum(1 for q in doc_questions if q['conversation_type'] == 'single_turn')}")
    print(f"   - Multi-turn: {sum(1 for q in doc_questions if q['conversation_type'] == 'multi_turn')}")
    print(f"   - Total with follow-ups: {sum(len(q['followup_questions']) for q in doc_questions)}")

print(f"\n{'='*70}")
print(f"✅ TOTAL QUESTIONS GENERATED: {len(all_questions)}")
print(f"   - Multi-turn conversations: {sum(1 for q in all_questions if q['has_followup'])}")
print(f"   - Total follow-up questions: {sum(len(q['followup_questions']) for q in all_questions)}")
print(f"{'='*70}")
# Out:
# ======================================================================
# Generating questions for: othp33.pdf
# ======================================================================
#
# Question type breakdown:
#   - chatbot_style: 5
#   - conditional: 2
#   - scenario: 10
#   - descriptive: 5
#   - analytical: 5
#   - compliance: 2
#   - multi_hop: 5
#   - direct_factual: 5
#   - comparative: 2
#   - procedural: 7
# Generating: 100%|██████████| 20/20 [01:38<00:00,  4.93s/it]
# ✅ Generated 20 questions
#    - Single-turn: 9
#    - Multi-turn: 11
#    - Total with follow-ups: 17
#
# ======================================================================
# ✅ TOTAL QUESTIONS GENERATED: 20
#    - Multi-turn conversations: 11
#    - Total follow-up questions: 17
# ======================================================================

# %% [markdown]
# ## 8. Review Sample Questions

# %%
len(all_questions)
# Out:
# 20

# %%
# Display sample questions
print("\n📋 SAMPLE GENERATED QUESTIONS\n")
print("="*80)

for i, qa in enumerate(all_questions, 1):
    print(f"\n🔷 QUESTION {i}")
    print(f"   Type: {qa.get('question_type', 'unknown').upper()}")
    print(f"   Conversation: {qa.get('conversation_type', 'unknown').upper()}")
    print(f"   Source: {qa.get('source_file', 'unknown')}")
    print(f"   Region: {qa.get('region_id', 0) + 1}")
    
    print(f"\n   Q: {qa['question']}")
    answer_preview = qa['answer'][:150] + "..." if len(qa['answer']) > 150 else qa['answer']
    print(f"   A: {answer_preview}")
    print(f"   Complexity: {qa.get('complexity', 'N/A')}")
    
    if qa.get('has_followup'):
        print(f"\n   📎 FOLLOW-UP QUESTIONS: {len(qa['followup_questions'])}")
        for j, followup in enumerate(qa['followup_questions'], 1):
            print(f"      {j}. {followup['followup_question']}")
            print(f"         Type: {followup.get('followup_type', 'unknown')}")
    
    print("\n" + "-"*80)

print("\n💡 Review the questions. If satisfied, set TEST_MODE = False for full generation.")
# Out:
# 📋 SAMPLE GENERATED QUESTIONS
#
# ================================================================================
#
# 🔷 QUESTION 1
#    Type: SCENARIO
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 1
#
#    Q: A policy analyst at the Bank of England is tasked with preparing a briefing on cross-border collaboration for central bank digital currencies (CBDCs). The analyst needs to reference both the foundational principles and the core features of CBDCs as agreed upon by the group of central banks mentioned in Report no 1. What steps should the analyst take to ensure that the briefing accurately reflects the collaborative approach outlined by the European Central Bank, Bank of Japan, Sveriges Riksbank, Swiss National Bank, Board of Governors Federal Reserve System, Bank of Canada, and Bank for International Settlements?
#    A: The analyst should first access the publication 'Central bank digital currencies: foundational principles and core features, Report no 1,' which is av...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 2
#    Type: ANALYTICAL
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 1
#
#    Q: Evaluate how the design choices outlined in Section 4.1 influence the key trade-offs identified in Section 4.3 when developing a CBDC.
#    A: The design choices discussed in Section 4.1, such as decisions on the architecture (centralized vs decentralized), degree of privacy, access models, a...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 3
#    Type: PROCEDURAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 1
#
#    Q: What are the procedural steps that central banks should follow before deciding to launch a CBDC, according to the group’s recommendations?
#    A: Before deciding to launch a CBDC, central banks should: (1) conduct an informed judgment assessing potential adverse impacts on bank funding and finan...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 1
#       1. You mentioned safeguards in the design of a CBDC to manage risks—could you elaborate on what specific safeguards central banks might implement, and how these would work in practice?
#          Type: deeper_detail
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 4
#    Type: PROCEDURAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 1
#
#    Q: What are the step-by-step procedures central banks follow to provide central bank money to the public and to banks or other financial companies, as described in the introduction?
#    A: According to the introduction, central banks provide central bank money to the public through cash and to banks and other financial companies via rese...
#    Complexity: easy
#
#    📎 FOLLOW-UP QUESTIONS: 1
#       1. Given that the use of cash is declining and private digital money is becoming more prevalent, how are central banks adapting their procedures for providing central bank money to the public in a digital economy?
#          Type: consequence
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 5
#    Type: CONDITIONAL
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 1
#
#    Q: If a central bank wishes for its CBDC to effectively fulfil public policy objectives, what must it ensure regarding the design and underlying system of the CBDC?
#    A: If a central bank wishes for its CBDC to effectively fulfil public policy objectives, it must ensure that a suitable design for the CBDC and its under...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 6
#    Type: ANALYTICAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 2
#
#    Q: Evaluate the key differences in the decision-making process for a central bank when considering enabling privately issued liabilities matched with central bank money versus issuing a CBDC, based on the provided context.
#    A: The decision-making process for a central bank to enable privately issued liabilities matched with central bank money is fundamentally different from ...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. Are there any circumstances where a central bank might choose to enable privately issued liabilities matched with central bank money and also issue a CBDC at the same time? If so, what unique challenges or considerations would arise from managing both arrangements concurrently?
#          Type: exception
#       2. Are there any circumstances in which a central bank might decide to both enable privately issued liabilities matched with central bank money and issue a CBDC simultaneously? If so, what unique challenges or considerations would arise from managing both approaches within the same payment system?
#          Type: exception
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 7
#    Type: DIRECT_FACTUAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 2
#
#    Q: Why is defending against cyber attacks more difficult in a general purpose CBDC system compared to current wholesale central bank systems?
#    A: Defending against cyber attacks is more difficult in a general purpose CBDC system because the number of endpoints is significantly larger than those ...
#    Complexity: easy
#
#    📎 FOLLOW-UP QUESTIONS: 1
#       1. Are there any strategies or technologies that can help mitigate the increased cybersecurity risks associated with the larger number of endpoints in a general purpose CBDC system?
#          Type: deeper_detail
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 8
#    Type: MULTI_HOP
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 2
#
#    Q: If a central bank is designing a CBDC system to facilitate fiscal transfers during a crisis, such as the Covid-19 pandemic, what are the key policy considerations regarding payments data access, and which domestic agencies must be coordinated with to balance public privacy with the reduction of illegal activity?
#    A: When designing a CBDC system for facilitating fiscal transfers in a crisis, central banks must determine who can access specific parts of payments dat...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. Are there any circumstances under which certain government agencies could be granted broader access to CBDC payments data during a crisis, even if this might temporarily override standard privacy protections? If so, what safeguards would need to be in place to prevent misuse?
#          Type: exception
#       2. Are there any circumstances under which certain domestic agencies, like law enforcement or intelligence services, could be granted broader access to CBDC payments data than originally intended, and how would such exceptions be managed to protect public privacy?
#          Type: exception
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 9
#    Type: DIRECT_FACTUAL
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 2
#
#    Q: What are two basic technical methods by which CBDC systems can improve interoperability for cross-border payments, as described in the document?
#    A: Two basic technical methods by which CBDC systems can improve interoperability for cross-border payments are: (1) reducing barriers to membership of b...
#    Complexity: easy
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 10
#    Type: COMPLIANCE
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 2
#
#    Q: What compliance challenges are associated with using a central bank digital currency (CBDC) for direct transfers to the public, such as 'helicopter drops', particularly regarding the identification of recipients and the separation between monetary and fiscal policy?
#    A: The use of a CBDC for direct transfers to the public, such as 'helicopter drops', raises compliance challenges primarily in two areas: (1) identifying...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. Given the compliance risks you outlined, are there any specific scenarios where the use of a CBDC for direct transfers could be justified despite the blurring of monetary and fiscal policy boundaries—for example, during severe economic crises or emergencies?
#          Type: exception
#       2. Are there any circumstances under which a CBDC could be used for direct transfers without significantly blurring the line between monetary and fiscal policy, or is this risk inherent to the approach?
#          Type: exception
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 11
#    Type: SCENARIO
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 3
#
#    Q: A central bank in a jurisdiction with a unique legal and financial system is evaluating the issuance of a CBDC. During the assessment, the bank identifies opportunities such as reducing illegal activity and enabling programmable money, but also notes that these opportunities do not directly align with its core public policy objectives. As the lead policy advisor, what should the central bank prioritize when deciding whether to proceed with CBDC issuance, and how should it address opportunities that are considered secondary to its main objectives?
#    A: The central bank should prioritize evaluating how issuance of a CBDC would support its core public policy objectives, such as monetary and financial s...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 12
#    Type: DESCRIPTIVE
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 3
#
#    Q: Describe the respective roles of public authorities, particularly central banks, and private agents such as commercial banks and payment service providers in ensuring a safe, efficient, and accessible payments ecosystem.
#    A: In the payments ecosystem, public authorities—especially central banks—play a crucial role alongside private agents like commercial banks and payment ...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 13
#    Type: PROCEDURAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 3
#
#    Q: What are the step-by-step procedures that entities must follow to ensure their CBDC transfer, storage, or custody services conform to the appropriate regulatory and prudential standards applicable to similar cash or digital money services?
#    A: Entities offering transfer, storage, or custody services for CBDC must follow these procedures: (1) Identify all relevant regulatory and prudential st...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 1
#       1. Are there any circumstances where an entity providing CBDC services might be exempt from certain regulatory or prudential standards that apply to cash or existing digital money services?
#          Type: exception
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 14
#    Type: MULTI_HOP
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 3
#
#    Q: In the context of CBDC ledger design, if a central bank implements a combination ledger structure (where the centralised ledger records only the total CBDC issued and individual balances are stored locally on devices), what are the implications for payment authentication methods and integration with digital identity verification systems required for KYC and transaction monitoring?
#    A: When a central bank uses a combination ledger structure—centralised for aggregate CBDC issuance and decentralised for individual balances on local dev...
#    Complexity: hard
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 15
#    Type: SCENARIO
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 3
#
#    Q: A central bank is considering the launch of a CBDC to meet specific policy goals. During initial planning, the technology team presents several complementary technologies that could support the core features of the CBDC. However, the policy team is concerned about the reliability and suitability of these technologies. What steps should the project lead take to address these concerns and ensure the chosen technologies meet the policy objectives?
#    A: The project lead should organize extensive practical testing and experimentation of the proposed technologies, as highlighted in Section 4.2 Technolog...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 16
#    Type: SCENARIO
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 4
#
#    Q: A central bank in a mid-sized jurisdiction is considering launching a central bank digital currency (CBDC) that offers interest to users. During stakeholder meetings, commercial banks express concerns about potential financial stability risks, while technology partners highlight the operational ease of calculating and paying interest using a centralised ledger. However, end users express a strong preference for peer-to-peer and offline payment capabilities, which may be limited by a purely centralised system. As the project lead, what steps should the central bank take to address these competing pressures and clarify the best approach for its jurisdiction?
#    A: The central bank should begin with detailed engagement with all stakeholders, including commercial banks, technology partners, end users, and other ec...
#    Complexity: hard
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. You've mentioned that combining centralised and decentralised ledger solutions could address some user concerns but adds complexity. Can you elaborate on what specific operational or security challenges might arise from integrating both types of ledgers, and how the central bank could mitigate these risks?
#          Type: deeper_detail
#       2. Given that introducing an interest-bearing CBDC could impact financial stability by potentially shifting deposits away from commercial banks, are there specific safeguards or design mechanisms the central bank could implement to mitigate these risks while still offering interest and supporting peer-to-peer and offline payments?
#          Type: deeper_detail
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 17
#    Type: CONDITIONAL
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 4
#
#    Q: If a central bank designs a CBDC that is not easily convertible or is costly to use, what potential impact could this have on the CBDC’s ability to meet public policy objectives as outlined in the concluding thoughts?
#    A: If a CBDC is not easily convertible or is costly to use, it may fail to deliver on key public policy objectives identified by central banks, such as a...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. Are there any circumstances in which a CBDC that is not fully convertible or is somewhat costly to use might still achieve certain public policy objectives, or would these shortcomings always undermine its effectiveness?
#          Type: exception
#       2. Are there any circumstances where a CBDC might intentionally be designed with limited convertibility or higher costs, and if so, what specific policy objectives could justify such a design?
#          Type: exception
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 18
#    Type: MULTI_HOP
#    Conversation: SINGLE_TURN
#    Source: othp33.pdf
#    Region: 4
#
#    Q: Given that CBDC design is primarily focused on domestic users and payment systems, and considering that economic design decisions such as CBDC remuneration policy and banking system impact controls vary by jurisdiction, what must policymakers consider when implementing a CBDC to ensure it meets their domestic requirements while addressing differences from other jurisdictions?
#    A: Policymakers must first recognize that a CBDC cannot be implemented as an 'off-the-shelf' solution due to persistent differences in policy and design ...
#    Complexity: medium
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 19
#    Type: COMPARATIVE
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 4
#
#    Q: Compare the roles of the BIS Innovation Hub and the CPMI in supporting cross-border CBDC interoperability, as described in the document.
#    A: According to the document, the BIS Innovation Hub is tasked with exploring further technological experiments that could enable interoperability and cr...
#    Complexity: medium
#
#    📎 FOLLOW-UP QUESTIONS: 1
#       1. Are there any situations where the BIS Innovation Hub and the CPMI might have overlapping responsibilities, and if so, how do they coordinate to avoid duplication of efforts in promoting cross-border CBDC interoperability?
#          Type: clarification
#
# --------------------------------------------------------------------------------
#
# 🔷 QUESTION 20
#    Type: CHATBOT_STYLE
#    Conversation: MULTI_TURN
#    Source: othp33.pdf
#    Region: 4
#
#    Q: Can you help me understand what the ledger environment in February refers to in relation to central bank digital currency projects?
#    A: Certainly. The reference to the ledger environment in February within the context of central bank digital currency (CBDC) projects likely pertains to ...
#    Complexity: easy
#
#    📎 FOLLOW-UP QUESTIONS: 2
#       1. Could you explain what specific features or components are typically included in a CBDC ledger environment during these February trial phases, and how they might differ from those used in later, more permanent implementations?
#          Type: deeper_detail
#       2. Could you elaborate on what specific features or criteria define a 'ledger environment' in the context of these CBDC projects, and how it might differ between countries like Sweden and Canada based on the reports you mentioned?
#          Type: deeper_detail
#
# --------------------------------------------------------------------------------
#
# 💡 Review the questions. If satisfied, set TEST_MODE = False for full generation.

# %% [markdown]
# ## 9. Convert to DataFrame with Complete Classification

# %%
# Flatten to rows with full classification
flat_questions = []

for qa in all_questions:
    # Initial question
    question_id = f"Q{len(flat_questions) + 1}"
    
    flat_qa = {
        'question_id': question_id,
        'source_file': qa.get('source_file'),
        'region_id': qa.get('region_id', 0) + 1,
        'chunk_index': qa.get('chunk_index', 0),
        
        # Question content
        'question': qa['question'],
        'answer': qa['answer'],
        
        # Classification columns
        'conversation_type': qa.get('conversation_type', 'single_turn'),
        'turn_number': 1,
        'parent_question_id': None,
        'is_followup': False,
        
        'question_style': qa.get('question_type', 'unknown'),
        'question_type': qa.get('question_type', 'unknown'),
        'complexity_level': qa.get('complexity', 'medium'),
        
        'has_context': qa.get('conversation_type') == 'multi_turn',
        'generation_method': 'custom',
        
        'references': ', '.join(qa.get('references', [])) if qa.get('references') else '',
    }
    flat_questions.append(flat_qa)
    
    parent_id = question_id
    
    # Follow-up questions
    for turn_num, followup in enumerate(qa.get('followup_questions', []), 2):
        followup_id = f"Q{len(flat_questions) + 1}"
        
        followup_qa = {
            'question_id': followup_id,
            'source_file': qa.get('source_file'),
            'region_id': qa.get('region_id', 0) + 1,
            'chunk_index': qa.get('chunk_index', 0),
            
            'question': followup['followup_question'],
            'answer': followup['followup_answer'],
            
            'conversation_type': 'multi_turn',
            'turn_number': turn_num,
            'parent_question_id': parent_id,
            'is_followup': True,
            
            'question_style': followup.get('followup_type', 'followup'),
            'question_type': f"followup_{followup.get('followup_type', 'unknown')}",
            'complexity_level': 'medium',
            
            'has_context': True,
            'generation_method': 'custom',
            
            'references': '',
        }
        flat_questions.append(followup_qa)

df = pd.DataFrame(flat_questions)

print(f"✅ DataFrame created with {len(df)} total questions")
print(f"\nColumns: {', '.join(df.columns.tolist())}")
print(f"\nBreakdown:")
print(f"   - Initial questions: {len(df[df['is_followup'] == False])}")
print(f"   - Follow-up questions: {len(df[df['is_followup'] == True])}")
print(f"   - Single-turn: {len(df[df['conversation_type'] == 'single_turn'])}")
print(f"   - Multi-turn: {len(df[df['conversation_type'] == 'multi_turn'])}")

# Display sample
print("\nSample DataFrame:")
display(df[['question_id', 'question_type', 'conversation_type', 'turn_number', 'parent_question_id']].head(15))
# Out:
# ✅ DataFrame created with 37 total questions
#
# Columns: question_id, source_file, region_id, chunk_index, question, answer, conversation_type, turn_number, parent_question_id, is_followup, question_style, question_type, complexity_level, has_context, generation_method, references
#
# Breakdown:
#    - Initial questions: 20
#    - Follow-up questions: 17
#    - Single-turn: 9
#    - Multi-turn: 28
#
# Sample DataFrame:
#    question_id           question_type conversation_type  turn_number  \
# 0           Q1                scenario       single_turn            1
# 1           Q2              analytical       single_turn            1
# 2           Q3              procedural        multi_turn            1
# 3           Q4  followup_deeper_detail        multi_turn            2
# 4           Q5              procedural        multi_turn            1
# 5           Q6    followup_consequence        multi_turn            2
# 6           Q7             conditional       single_turn            1
# 7           Q8              analytical        multi_turn            1
# 8           Q9      followup_exception        multi_turn            2
# 9          Q10      followup_exception        multi_turn            3
# 10         Q11          direct_factual        multi_turn            1
# 11         Q12  followup_deeper_detail        multi_turn            2
# 12         Q13               multi_hop        multi_turn            1
# 13         Q14      followup_exception        multi_turn            2
# 14         Q15      followup_exception        multi_turn            3
#
#    parent_question_id
# 0                None
# 1                None
# 2                None
# 3                  Q3
# 4                None
# 5                  Q5
# 6                None
# 7                None
# 8                  Q8
# 9                  Q8
# 10               None
# 11                Q11
# 12               None
# 13                Q13
# 14                Q13

# %% [markdown]
# ## 10. Coverage Analysis

# %%
# Analyze coverage
print("\n📊 COVERAGE ANALYSIS\n")
print("="*70)

# Spatial coverage
print("\n1. Spatial Coverage (by region):")
region_coverage = df.groupby(['source_file', 'region_id']).size().unstack(fill_value=0)
print(region_coverage)

# Question type distribution
print("\n2. Question Type Distribution:")
type_dist = df['question_type'].value_counts()
print(type_dist)

# Conversation type
print("\n3. Conversation Type:")
conv_dist = df['conversation_type'].value_counts()
print(conv_dist)
print(f"   Multi-turn ratio: {conv_dist.get('multi_turn', 0) / len(df) * 100:.1f}%")

# Complexity distribution
print("\n4. Complexity Distribution:")
complexity_dist = df['complexity_level'].value_counts()
print(complexity_dist)

print("\n" + "="*70)

# %% [markdown]
# ## 11. Export Test Set

# %%
OUTPUT_DIR = "./outputs"
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

# Export full test set with all classification columns
full_file = f"{OUTPUT_DIR}/testset_full_classified.csv"
df.to_csv(full_file, index=False)
print(f"✅ Exported: {full_file}")

# Export simple format (for RAG evaluation)
simple_df = df[['question', 'answer', 'source_file']].copy()
simple_df.columns = ['question', 'ground_truth', 'source']
simple_file = f"{OUTPUT_DIR}/testset_simple.csv"
simple_df.to_csv(simple_file, index=False)
print(f"✅ Exported: {simple_file}")

# Export conversation chains
multiturn_df = df[df['conversation_type'] == 'multi_turn'].copy()
if len(multiturn_df) > 0:
    chains_file = f"{OUTPUT_DIR}/conversation_chains.csv"
    multiturn_df.to_csv(chains_file, index=False)
    print(f"✅ Exported: {chains_file}")
    print(f"   {len(multiturn_df)} multi-turn questions")

# Export summary
summary = {
    'total_questions': len(df),
    'initial_questions': len(df[df['is_followup'] == False]),
    'followup_questions': len(df[df['is_followup'] == True]),
    'single_turn': len(df[df['conversation_type'] == 'single_turn']),
    'multi_turn': len(df[df['conversation_type'] == 'multi_turn']),
    'question_types': df['question_type'].value_counts().to_dict(),
    'questions_per_document': df.groupby('source_file').size().to_dict(),
    'region_coverage': df.groupby('region_id').size().to_dict(),
}

summary_file = f"{OUTPUT_DIR}/testset_summary.json"
with open(summary_file, 'w') as f:
    json.dump(summary, f, indent=2)
print(f"✅ Exported: {summary_file}")

print(f"\n{'='*70}")
print("📊 SUMMARY:")
print(json.dumps(summary, indent=2))
print(f"{'='*70}")
# Out:
# ✅ Exported: ./outputs/testset_full_classified.csv
# ✅ Exported: ./outputs/testset_simple.csv
# ✅ Exported: ./outputs/conversation_chains.csv
#    28 multi-turn questions
# ✅ Exported: ./outputs/testset_summary.json
#
# ======================================================================
# 📊 SUMMARY:
# {
#   "total_questions": 37,
#   "initial_questions": 20,
#   "followup_questions": 17,
#   "single_turn": 9,
#   "multi_turn": 28,
#   "question_types": {
#     "followup_exception": 9,
#     "followup_deeper_detail": 6,
#     "scenario": 4,
#     "procedural": 3,
#     "multi_hop": 3,
#     "analytical": 2,
#     "conditional": 2,
#     "direct_factual": 2,
#     "followup_consequence": 1,
#     "compliance": 1,
#     "descriptive": 1,
#     "comparative": 1,
#     "followup_clarification": 1,
#     "chatbot_style": 1
#   },
#   "questions_per_document": {
#     "othp33.pdf": 37
#   },
#   "region_coverage": {
#     "1": 7,
#     "2": 12,
#     "3": 6,
#     "4": 12
#   }
# }
# ======================================================================

# %% [markdown]
# ## 12. Visualization

# %%
# Create visualizations
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Question type distribution
type_counts = df['question_type'].value_counts().head(10)
axes[0, 0].barh(range(len(type_counts)), type_counts.values)
axes[0, 0].set_yticks(range(len(type_counts)))
axes[0, 0].set_yticklabels(type_counts.index)
axes[0, 0].set_xlabel('Count')
axes[0, 0].set_title('Question Type Distribution')
axes[0, 0].invert_yaxis()

# 2. Conversation type
conv_counts = df['conversation_type'].value_counts()
axes[0, 1].pie(conv_counts.values, labels=conv_counts.index, autopct='%1.1f%%')
axes[0, 1].set_title('Single-turn vs Multi-turn')

# 3. Spatial coverage
region_counts = df['region_id'].value_counts().sort_index()
axes[1, 0].bar(region_counts.index, region_counts.values)
axes[1, 0].set_xlabel('Region')
axes[1, 0].set_ylabel('Questions')
axes[1, 0].set_title('Spatial Coverage by Region')
axes[1, 0].set_xticks(region_counts.index)

# 4. Complexity distribution
complexity_counts = df['complexity_level'].value_counts()
axes[1, 1].bar(range(len(complexity_counts)), complexity_counts.values)
axes[1, 1].set_xticks(range(len(complexity_counts)))
axes[1, 1].set_xticklabels(complexity_counts.index)
axes[1, 1].set_ylabel('Count')
axes[1, 1].set_title('Complexity Distribution')

plt.tight_layout()
viz_file = f"{OUTPUT_DIR}/testset_analysis.png"
plt.savefig(viz_file, dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Visualization saved: {viz_file}")

# %% [markdown]
# ## ✅ Complete!
#
# ### 📁 Generated Files:
# 1. `testset_full_classified.csv` - Complete test set with all classification columns
# 2. `testset_simple.csv` - Simple format (question, ground_truth, source)
# 3. `conversation_chains.csv` - Multi-turn conversations only
# 4. `testset_summary.json` - Statistics and metadata
# 5. `testset_analysis.png` - Visualizations
#
# ### 🎯 Features Included:
# ✅ All question types (10+ types)
# ✅ Multi-turn conversations with follow-ups
# ✅ Complete classification columns
# ✅ Spatial coverage guarantee
# ✅ Quality generation with context
# ✅ No RAGAS dependency
#
# ### 🔄 Next Steps:
# 1. Review sample questions above
# 2. If satisfied, set `TEST_MODE = False` and run again
# 3. Adjust `question_type_distribution` in config if needed
# 4. Use generated test set for RAG evaluation
